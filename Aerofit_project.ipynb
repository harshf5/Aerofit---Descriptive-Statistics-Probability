# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  1) Problem Statement

# %% [markdown]
# The objective of this project is to provide Aerofit with data-driven insignts that can assist them in deciding which types ofproducts to recommend to new customers and provide better recomendation for the treadmills by  Performing descriptive analytics to create a customer profile for each AeroFit treadmill product by developing appropriate tables and charts.

# %%
data=pd.read_csv('aerofit_treadmill.csv')
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
data.shape
# Out:
# (180, 9)

# %%
data.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
data.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
print("The total length of the observation : ", len(data))
# Out:
# The total length of the observation :  180

# %%
print('The total null values in each column :')
data.isnull().sum()
# Out:
# The total null values in each column :
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
data['Product'].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %%
data["Product"].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
data.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# Observation

# %% [markdown]
# There are no missing values in the data.
#
# There are 3 unique products in the dataset. i.e KP281, KP481 and KP781
# KP281 is the most frequent product.
#
# Minimum & Maximum age of the person is 18 & 50, mean is 28.79 and 75% of persons have age less than or equal to 33.
#
# Most of the people are having 16 years of education i.e. 75% of persons are having education <= 16 years.
#
# Out of 180 data points, 104's gender is Male and rest are the female.
#
# In this dataset, majority of the people are married i.e 107 of them.
#
# Standard deviation for Income & Miles is very high. These variables might have the outliers in it.

# %%
data['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
sns.countplot(data=data,x='MaritalStatus')

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
sns.boxplot(data=data, x="Age", orient='h', ax=axis[0,0])
sns.boxplot(data=data, x="Education", orient='h', ax=axis[0,1])
sns.boxplot(data=data, x="Usage", orient='h', ax=axis[1,0])
sns.boxplot(data=data, x="Fitness", orient='h', ax=axis[1,1])
sns.boxplot(data=data, x="Income", orient='h', ax=axis[2,0])
sns.boxplot(data=data, x="Miles", orient='h', ax=axis[2,1])
plt.show()

# %% [markdown]
# Observation :
#
# There are very little outliers in age,education,usage and fitness.
# While Income and Miles column has a lot of outliers

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
sns.histplot(data=data, x="Age",  ax=axis[0,0])
sns.histplot(data=data, x="Education",  ax=axis[0,1])
sns.histplot(data=data, x="Usage",  ax=axis[1,0])
sns.histplot(data=data, x="Fitness",  ax=axis[1,1])
sns.histplot(data=data, x="Income",  ax=axis[2,0])
sns.histplot(data=data, x="Miles",  ax=axis[2,1])
plt.show()

# %% [markdown]
# Observation:
# Most of Aerofit products are used by :
#         People of age between 20 to 35 .
#         People with education 14 to 16 years .
#         People using it fot 3 or 4 days a week.
#         People having fitness greater than 3.
#         People having salary between 40k to 70k.
#         People walking/running 50 to 120 miles.

# %%
plt.axis('equal')
data['Gender'].value_counts().plot(kind='pie', autopct = "%.2f%%",title='Percentage of Male and Female')
plt.show()

# %%
plt.axis('equal')
data['MaritalStatus'].value_counts().plot(kind='pie', autopct = "%.2f%%",title='Percentage of MaritalStatus')
plt.show()

# %%
sns.pairplot(data,
    x_vars=["Age", "Usage", "Income",'Miles'],
    y_vars=["Age", "Usage", "Income","Fitness",'Miles'],
             hue='Product')

# %% [markdown]
# Observation:
# It can be observe that as the miles ,usage ,fitness and income get higher, people prefer KP981 product.
# BUt age has not effect on buying any particular type of product.

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# #Univariate analysis

# %%
# %%capture --no-display 
df1=data.loc[data['Product']=='KP281'] 
df2=data.loc[data['Product']=='KP481']
df3=data.loc[data['Product']=='KP781']

plt.plot(df1["Income"],np.zeros_like(df1["Income"]))
plt.plot(df2["Income"],np.zeros_like(df2["Income"]))
plt.plot(df3["Income"],np.zeros_like(df3["Income"]))
plt.xlabel("")
plt.show()

# %% [markdown]
# Observation :
#     income of people buying kp781 are more.

# %%
data.columns

# %%
data.groupby('Product')['Usage'].count()
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: Usage, dtype: int64

# %%
fig, axis = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
sns.countplot(data=data,x='Product',hue="MaritalStatus",ax=axis[0])
sns.countplot(data=data,x='Product',hue="Gender",ax=axis[1])

# %% [markdown]
# Observation:
# Clearly partnered people buy more products than the single one.
# For the KP781 product, Males tend to buy it more. while for the rest of the product, sale to both genders is quite comparable.

# %%
list1=data["Usage"].unique()
list1
# Out:
# array([3, 2, 4, 5, 6, 7], dtype=int64)

# %%
pd.crosstab(index=data['Gender'],columns=data["Product"],margins=True)
# Out:
# Product  KP281  KP481  KP781  All
# Gender
# Female      40     29      7   76
# Male        40     31     33  104
# All         80     60     40  180

# %%
pd.crosstab(index=data['Gender'],columns=data["Product"],margins=True,normalize=True)
# Out:
# Product     KP281     KP481     KP781       All
# Gender
# Female   0.222222  0.161111  0.038889  0.422222
# Male     0.222222  0.172222  0.183333  0.577778
# All      0.444444  0.333333  0.222222  1.000000

# %% [markdown]
# Observation:
# Overall 57.8% male and 42.3% female have bought the aerofit products.
# While KP281 was bought the most at 44.4 % .

# %%
data['Income'].agg(['max','min'])
# Out:
# max    104581
# min     29562
# Name: Income, dtype: int64

# %%
sns.scatterplot(x = "Product", y = "Income", hue = "Gender",  data = data)

# %%
fig, axis = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
sns.barplot(data=data,x='Product',y='Education',ax=axis[0])
sns.barplot(data=data,x='Product',y='Miles',ax=axis[1])

# %% [markdown]
# Observation :
# More educated people and people with higher salary tends to buy  KP781.
# People who wish to walk more tends to buy KP781.

# %%
data.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
pd.crosstab(index=data['MaritalStatus'],columns=data["Product"],margins=True,normalize=True)
# Out:
# Product           KP281     KP481     KP781       All
# MaritalStatus
# Partnered      0.266667  0.200000  0.127778  0.594444
# Single         0.177778  0.133333  0.094444  0.405556
# All            0.444444  0.333333  0.222222  1.000000

# %% [markdown]
# Observation:
# partnered People tends to buy 60% of the products.
# While Partnered people buy 27% KP281 of the total sale of products.

# %%
col = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']
sns.set_style("whitegrid")
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))
fig.subplots_adjust(top=1.2)
count = 0
for i in range(2):
    for j in range(3):
        sns.boxplot(data=data, x='Product', y=col[count], ax=axs[i,j], palette='husl')
        axs[i,j].set_title(f"Product vs {col[count]}", pad=12, fontsize=13)
        count += 1

# %% [markdown]
# Observation:
# 1)Product Vs Age:Median age for KP281 an Kp481 is same. IQR Age for KP781 is small and there are more outliers in KP781 compared to other products.
#
# 2)Product vs Education : No of years spent on education is same for both KP281 and KP481 while for KP781, its mostly used by people who has more no of years of educationi.e people having more than 16 years of education are more likely to buy.
#
# 3)Product vs usage: People who use treadmills more tends to buy KP781 i.e people using it more than 4 times a week are more likely to buy this product.
#
# 4)Product vs fitness:Having more fitness means they are more likely to buy KP781.
#
# 5)Product vs Income: People having income around 60k and more are likely to buy KP781. While people having significantly lower income tends to buy other product.
#
# 6)Product vs Miles: People who tends to walk more than 115 miles per week will buy KP781 .
#
# So people having higher income,higher usage per week, high miles to cover,more education make them buy KP781.

# %% [markdown]
# # Probabilities

# %%
data["Product"].value_counts(normalize=True)
# Out:
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: Product, dtype: float64

# %% [markdown]
# Obserrvation: Out of total product, 44.4% is KP281, 33.3% is KP482 and 22.2% is KP781

# %%
d1=data["Gender"].value_counts(normalize=True)
d1
# Out:
# Male      0.577778
# Female    0.422222
# Name: Gender, dtype: float64

# %% [markdown]
# Observation:Out of total data 57.7 % are males and 42.3 are females.

# %%
data["MaritalStatus"].value_counts(normalize=True)
# Out:
# Partnered    0.594444
# Single       0.405556
# Name: MaritalStatus, dtype: float64

# %% [markdown]
# Observation: Out of total data 59.4 % are partnered and 40.1% are single

# %%
d2=pd.crosstab(index=data['Gender'],columns=data["Product"],margins=True)
d2
# Out:
# Product  KP281  KP481  KP781  All
# Gender
# Female      40     29      7   76
# Male        40     31     33  104
# All         80     60     40  180

# %% [markdown]
# #Contional Probability:

# %% [markdown]
# Probality of products given gender

# %%
print('P(Male) : ' + str(round(d1[0],2)))
print('P(Female) : ' + str(round(d1[1],2)))
print('\n')
males_num=data["Gender"].value_counts()[0]
females_num=data["Gender"].value_counts()[1]

f_281=round(d2['KP281']['Female'] /females_num ,2)
f_481=round(d2['KP481']['Female'] /females_num ,2)
f_781=round(d2['KP781']['Female'] /females_num ,2)

m_281=round(d2['KP281']['Male'] /males_num ,2)
m_481=round(d2['KP481']['Male'] /males_num ,2)
m_781=round(d2['KP781']['Male'] /males_num ,2)


print('P(KP281/Female) : '+  str(f_281))
print('P(KP481/Female) : '+  str(f_481))
print('P(KP781/Female) : '+  str(f_781))
print('\n')
print('P(KP281/Male) : '+  str(m_281))
print('P(KP481/Male) : '+  str(m_481))
print('P(KP781/Male) : '+  str(m_781))
# Out:
# P(Male) : 0.58
# P(Female) : 0.42
#
#
# P(KP281/Female) : 0.53
# P(KP481/Female) : 0.38
# P(KP781/Female) : 0.09
#
#
# P(KP281/Male) : 0.38
# P(KP481/Male) : 0.3
# P(KP781/Male) : 0.32

# %% [markdown]
# Probalities of product given Marital status

# %%
d3=data["MaritalStatus"].value_counts(normalize=True)
d3
# Out:
# Partnered    0.594444
# Single       0.405556
# Name: MaritalStatus, dtype: float64

# %%
d4=pd.crosstab(index=data['MaritalStatus'],columns=data["Product"],margins=True)
d4
# Out:
# Product        KP281  KP481  KP781  All
# MaritalStatus
# Partnered         48     36     23  107
# Single            32     24     17   73
# All               80     60     40  180

# %%
print('P(Partnered) : ' + str(round(d3[0],2)))
print('P(Single) : ' + str(round(d3[1],2)))
print('\n')
Partnered_num=data["MaritalStatus"].value_counts()[0]
Single_num=data["MaritalStatus"].value_counts()[1]

p_281=round(d4['KP281']['Partnered'] /Partnered_num ,2)
p_481=round(d4['KP481']['Partnered'] /Partnered_num ,2)
p_781=round(d4['KP781']['Partnered'] /Partnered_num ,2)

s_281=round(d4['KP281']['Single'] /Single_num ,2)
s_481=round(d4['KP481']['Single'] /Single_num ,2)
s_781=round(d4['KP781']['Single'] /Single_num ,2)


print('P(KP281/Partnered) : '+  str(p_281))
print('P(KP481/Partnered) : '+  str(p_481))
print('P(KP781/Partnered) : '+  str(p_781))
print('\n')
print('P(KP281/Single) : '+  str(s_281))
print('P(KP481/Single) : '+  str(s_481))
print('P(KP781/Single) : '+  str(s_781))
# Out:
# P(Partnered) : 0.59
# P(Single) : 0.41
#
#
# P(KP281/Partnered) : 0.45
# P(KP481/Partnered) : 0.34
# P(KP781/Partnered) : 0.21
#
#
# P(KP281/Single) : 0.44
# P(KP481/Single) : 0.33
# P(KP781/Single) : 0.23

# %% [markdown]
# Overall Observation:
#
# There are no missing values in the data.
#
# Minimum & Maximum age of the person is 18 & 50, mean is 28.79 and 75% of persons have age less than or equal to 33.
#
# There are very little outliers in age,education,usage and fitness. While Income and Miles column has a lot of outliers.
#
# It can be observe that as the miles ,usage ,fitness and income get higher, people prefer KP981 product. BUt age has not effect on buying any particular type of product.
#
# Clearly partnered people buy more products than the single one. For the KP781 product, Males tend to buy it more. while for the rest of the product, sale to both genders is quite comparable.
#
# Overall 57.8% male and 42.3% female have bought the aerofit products. While KP281 was bought the most at 44.4 % overall.
#
#  More educated people and people with higher salary tends to buy KP781. People who wish to walk more tends to buy KP781
#
#  partnered People tends to buy 60% of the products. While Partnered people buy 27% KP281 of the total sale of products.

# %% [markdown]
# Suggestion:
#
# Aerofit must target to sell KP781 to the people with higher salary and having marital status as Partnered and males and people having higher years of education.As they tends to buy this more.
#
# Since there are very less outliers to most of the category, so its clear that Aerofit sells its product to very limited bandwidth. so aerofit must plan to target people who are not buying its product. Like for example people of age between 18 and 50 only buy its product.
#
# Female buying KP781 has probaility of only 0.09 which is very less, something aerofit needs to work on. While buying KP281 has probility of 0.53 ,so aerofit has higher chance of selling KP281 to females. so they can target accordingly.
